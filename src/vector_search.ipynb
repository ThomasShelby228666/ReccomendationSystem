# %% [markdown]
# ## `vector_search.ipynb` - работа с векторной базой данных и векторным поиском
#
# **В данном блокноте происходит преобразование описаний фильмов в эмбеддинги с последующим сохранением в векторной базе данных**

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_text_splitters import CharacterTextSplitter
from langchain_chroma import Chroma

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import pandas as pd

movies = pd.read_csv("../data/movies_cleaned.csv")
movies
# Out:
#           id                  title  vote_average  vote_count    status  \
# 0      27205              Inception         8.364       34495  Released
# 1     157336           Interstellar         8.417       32571  Released
# 2        155        The Dark Knight         8.512       30619  Released
# 3      19995                 Avatar         7.573       29815  Released
# 4      24428           The Avengers         7.710       29166  Released
# ...      ...                    ...           ...         ...       ...
# 1223  529203  The Croods: A New Age         7.521        3508  Released
# 1224    9392            The Descent         6.957        3507  Released
# 1225   12153           White Chicks         6.919        3505  Released
# 1226    2832               Identity         7.180        3502  Released
# 1227    2123     Me, Myself & Irene         6.587        3501  Released
#
#      release_date     revenue  runtime  adult  \
# 0      2010-07-15   825532764      148  False
# 1      2014-11-05   701729206      169  False
# 2      2008-07-16  1004558444      152  False
# 3      2009-12-15  2923706026      162  False
# 4      2012-04-25  1518815515      143  False
# ...           ...         ...      ...    ...
# 1223   2020-11-25   215905815       95  False
# 1224   2005-07-08    57130027       99  False
# 1225   2004-06-23   113086475      109  False
# 1226   2003-04-25    90259536       90  False
# 1227   2000-06-22   149270999      116  False
#
#                          backdrop_path  ...  \
# 0     /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1     /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2     /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3     /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4     /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
# ...                                ...  ...
# 1223  /ytTQoYkdpsgtfDWrNFCei8Mfbxu.jpg  ...
# 1224  /70TIOrfkQli0Smsfjua2McaDPci.jpg  ...
# 1225  /di47xqYMCYpjqwnqNlO17X5qXMX.jpg  ...
# 1226  /7MwDOMrbjrKP3XQ5vw4cgB2DPaF.jpg  ...
# 1227  /8qLen3NLCVSu1I9aqGWbTUIoBLQ.jpg  ...
#
#                                                overview popularity  \
# 0     Cobb, a skilled thief who commits corporate es...     83.952
# 1     The adventures of a group of explorers who mak...    140.241
# 2     Batman raises the stakes in his war on crime. ...    130.643
# 3     In the 22nd century, a paraplegic Marine is di...     79.932
# 4     When an unexpected enemy emerges and threatens...     98.082
# ...                                                 ...        ...
# 1223  Searching for a safer habitat, the prehistoric...     63.456
# 1224  After a tragic accident, six friends reunite f...     23.007
# 1225  Two FBI agent brothers, Marcus and Kevin Copel...     54.851
# 1226  Complete strangers stranded at a remote desert...     27.747
# 1227  Rhode Island State Trooper Charlie Baileygates...     24.300
#
#                            poster_path  \
# 0     /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1     /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2     /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4      /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# ...                                ...
# 1223  /tbVZ3Sq88dZaCANlUcewQuHQOaE.jpg
# 1224  /mxFPI4KYBk5ri9cPteIS8jiDFgj.jpg
# 1225  /aHTUpo45qy9QYIOnVITGGqLoVcA.jpg
# 1226  /bnidwEvWNAVJ3Uco9wWtuzWAfrx.jpg
# 1227  /rvRrcbLbpn7UJGRH1JupgHOeJFq.jpg
#
#                                                 tagline  \
# 0                  Your mind is the scene of the crime.
# 1     Mankind was born on Earth. It was never meant ...
# 2                     Welcome to a world without rules.
# 3                           Enter the world of Pandora.
# 4                               Some assembly required.
# ...                                                 ...
# 1223               The future ain't what it used to be.
# 1224                           Scream your last breath.
# 1225                     They're going deep undercover.
# 1226                            The secret lies within.
# 1227                             From gentle to mental.
#
#                                              genres  \
# 0                Action, Science Fiction, Adventure
# 1                 Adventure, Drama, Science Fiction
# 2                    Drama, Action, Crime, Thriller
# 3       Action, Adventure, Fantasy, Science Fiction
# 4                Science Fiction, Action, Adventure
# ...                                             ...
# 1223  Animation, Family, Adventure, Fantasy, Comedy
# 1224                              Adventure, Horror
# 1225                                  Comedy, Crime
# 1226                              Mystery, Thriller
# 1227                                         Comedy
#
#                                    production_companies  \
# 0     Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1     Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2     DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3     Dune Entertainment, Lightstorm Entertainment, ...
# 4                                        Marvel Studios
# ...                                                 ...
# 1223           Universal Pictures, DreamWorks Animation
# 1224         Pathé, Celador Films, Northmen Productions
# 1225  Columbia Pictures, Revolution Studios, Wayans ...
# 1226                 Konrad Pictures, Columbia Pictures
# 1227          Conundrum Entertainment, 20th Century Fox
#
#                           production_countries  \
# 0     United Kingdom, United States of America
# 1     United Kingdom, United States of America
# 2     United Kingdom, United States of America
# 3     United States of America, United Kingdom
# 4                     United States of America
# ...                                        ...
# 1223                  United States of America
# 1224                            United Kingdom
# 1225                  United States of America
# 1226                  United States of America
# 1227                  United States of America
#
#                         spoken_languages  \
# 0     English, French, Japanese, Swahili
# 1                                English
# 2                      English, Mandarin
# 3                       English, Spanish
# 4                English, Hindi, Russian
# ...                                  ...
# 1223                             English
# 1224                             English
# 1225                             English
# 1226                             English
# 1227                     English, German
#
#                                                keywords  \
# 0     rescue, mission, dream, airplane, paris, franc...
# 1     rescue, future, spacecraft, race against time,...
# 2     joker, sadism, chaos, secret identity, crime f...
# 3     future, society, culture clash, space travel, ...
# 4     new york city, superhero, shield, based on com...
# ...                                                 ...
# 1223  sequel, prehistory, candid, playful, joyous, a...
# 1224  panic, darkness, mutant, expedition, cave, cla...
# 1225  undercover, fbi, cross dressing, car accident,...
# 1226  prostitute, prisoner, psychopath, nevada, dete...
# 1227  schizophrenia, road trip, ex-cop, aftercredits...
#
#                                         tagged_overview
# 0     tt1375666 Cobb, a skilled thief who commits co...
# 1     tt0816692 The adventures of a group of explore...
# 2     tt0468569 Batman raises the stakes in his war ...
# 3     tt0499549 In the 22nd century, a paraplegic Ma...
# 4     tt0848228 When an unexpected enemy emerges and...
# ...                                                 ...
# 1223  tt2850386 Searching for a safer habitat, the p...
# 1224  tt0435625 After a tragic accident, six friends...
# 1225  tt0381707 Two FBI agent brothers, Marcus and K...
# 1226  tt0309698 Complete strangers stranded at a rem...
# 1227  tt0183505 Rhode Island State Trooper Charlie B...
#
# [1228 rows x 24 columns]

# %% [markdown]
# **Сохраняем столбец `tagged_overview` в текстовый файл**

# %%
movies["tagged_overview"].to_csv(
    "../data/tagged_overview.txt",
    sep="\n",
    index=False,
    header=False
)

# %% [markdown]
# **Подготовка тектовых данных для векторного поиска**

# %%
raw_documents = TextLoader("../data/tagged_overview.txt", encoding="utf-8").load()
text_splitter = CharacterTextSplitter(chunk_size=1, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 294, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 406, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 307, which is longer than the specified 1
# Created a chunk of size 344, which is longer than the specified 1
# Created a chunk of size 500, which is longer than the specified 1
# Created a chunk of size 309, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 416, which is longer than the specified 1
# Created a chunk of size 142, which is longer than the specified 1
# Created a chunk of size 136, which is longer than the specified 1
# Created a chunk of size 398, which is longer than the specified 1
# Created a chunk of size 337, which is longer than the specified 1
# Created a chunk of size 191, which is longer than the specified 1
# Created a chunk of size 370, which is longer than the specified 1
# Created a chunk of size 179, which is longer than the specified 1
# Created a chunk of size 361, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 210, which is longer than the specified 1
# Created a chunk of size 404, which is longer than the specified 1
# Created a chunk of size 305, which is longer than the specified 1
# Created a chunk of size 438, which is longer than the specified 1
# Created a chunk of size 146, which is longer than the specified 1
# Created a chunk of size 569, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 280, which is longer than the specified 1
# Created a chunk of size 381, which is longer than the specified 1
# Created a chunk of size 776, which is longer than the specified 1
# Created a chunk of size 299, which is longer than the specified 1
# Created a chunk of size 338, which is longer than the specified 1
# Created a chunk of size 136, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 340, which is longer than the specified 1
# Created a chunk of size 241, which is longer than the specified 1
# Created a chunk of size 443, which is longer than the specified 1
# Created a chunk of size 360, which is longer than the specified 1
# Created a chunk of size 382, which is longer than the specified 1
# Created a chunk of size 279, which is longer than the specified 1
# Created a chunk of size 274, which is longer than the specified 1
# Created a chunk of size 453, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 404, which is longer than the specified 1
# Created a chunk of size 400, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 322, which is longer than the specified 1
# Created a chunk of size 157, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 391, which is longer than the specified 1
# Created a chunk of size 317, which is longer than the specified 1
# Created a chunk of size 353, which is longer than the specified 1
# Created a chunk of size 337, which is longer than the specified 1
# Created a chunk of size 155, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 297, which is longer than the specified 1
# Created a chunk of size 641, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 343, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 386, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 456, which is longer than the specified 1
# Created a chunk of size 738, which is longer than the specified 1
# Created a chunk of size 200, which is longer than the specified 1
# Created a chunk of size 515, which is longer than the specified 1
# Created a chunk of size 179, which is longer than the specified 1
# Created a chunk of size 191, which is longer than the specified 1
# Created a chunk of size 331, which is longer than the specified 1
# Created a chunk of size 313, which is longer than the specified 1
# Created a chunk of size 141, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 404, which is longer than the specified 1
# Created a chunk of size 476, which is longer than the specified 1
# Created a chunk of size 354, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 169, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 382, which is longer than the specified 1
# Created a chunk of size 648, which is longer than the specified 1
# Created a chunk of size 423, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 148, which is longer than the specified 1
# Created a chunk of size 500, which is longer than the specified 1
# Created a chunk of size 164, which is longer than the specified 1
# Created a chunk of size 363, which is longer than the specified 1
# Created a chunk of size 297, which is longer than the specified 1
# Created a chunk of size 415, which is longer than the specified 1
# Created a chunk of size 313, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 369, which is longer than the specified 1
# Created a chunk of size 372, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 378, which is longer than the specified 1
# Created a chunk of size 219, which is longer than the specified 1
# Created a chunk of size 372, which is longer than the specified 1
# Created a chunk of size 405, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 230, which is longer than the specified 1
# Created a chunk of size 154, which is longer than the specified 1
# Created a chunk of size 358, which is longer than the specified 1
# Created a chunk of size 412, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 152, which is longer than the specified 1
# Created a chunk of size 120, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 171, which is longer than the specified 1
# Created a chunk of size 301, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 259, which is longer than the specified 1
# Created a chunk of size 315, which is longer than the specified 1
# Created a chunk of size 136, which is longer than the specified 1
# Created a chunk of size 173, which is longer than the specified 1
# Created a chunk of size 207, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 358, which is longer than the specified 1
# Created a chunk of size 637, which is longer than the specified 1
# Created a chunk of size 218, which is longer than the specified 1
# Created a chunk of size 120, which is longer than the specified 1
# Created a chunk of size 466, which is longer than the specified 1
# Created a chunk of size 302, which is longer than the specified 1
# Created a chunk of size 131, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 303, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 412, which is longer than the specified 1
# Created a chunk of size 472, which is longer than the specified 1
# Created a chunk of size 139, which is longer than the specified 1
# Created a chunk of size 140, which is longer than the specified 1
# Created a chunk of size 329, which is longer than the specified 1
# Created a chunk of size 410, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 381, which is longer than the specified 1
# Created a chunk of size 265, which is longer than the specified 1
# Created a chunk of size 327, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 322, which is longer than the specified 1
# Created a chunk of size 181, which is longer than the specified 1
# Created a chunk of size 420, which is longer than the specified 1
# Created a chunk of size 186, which is longer than the specified 1
# Created a chunk of size 424, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 430, which is longer than the specified 1
# Created a chunk of size 168, which is longer than the specified 1
# Created a chunk of size 149, which is longer than the specified 1
# Created a chunk of size 421, which is longer than the specified 1
# Created a chunk of size 296, which is longer than the specified 1
# Created a chunk of size 356, which is longer than the specified 1
# Created a chunk of size 305, which is longer than the specified 1
# Created a chunk of size 396, which is longer than the specified 1
# Created a chunk of size 332, which is longer than the specified 1
# Created a chunk of size 402, which is longer than the specified 1
# Created a chunk of size 381, which is longer than the specified 1
# Created a chunk of size 324, which is longer than the specified 1
# Created a chunk of size 350, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 134, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 294, which is longer than the specified 1
# Created a chunk of size 587, which is longer than the specified 1
# Created a chunk of size 274, which is longer than the specified 1
# Created a chunk of size 630, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 203, which is longer than the specified 1
# Created a chunk of size 438, which is longer than the specified 1
# Created a chunk of size 481, which is longer than the specified 1
# Created a chunk of size 311, which is longer than the specified 1
# Created a chunk of size 364, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 327, which is longer than the specified 1
# Created a chunk of size 201, which is longer than the specified 1
# Created a chunk of size 343, which is longer than the specified 1
# Created a chunk of size 330, which is longer than the specified 1
# Created a chunk of size 147, which is longer than the specified 1
# Created a chunk of size 301, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 483, which is longer than the specified 1
# Created a chunk of size 363, which is longer than the specified 1
# Created a chunk of size 164, which is longer than the specified 1
# Created a chunk of size 262, which is longer than the specified 1
# Created a chunk of size 336, which is longer than the specified 1
# Created a chunk of size 436, which is longer than the specified 1
# Created a chunk of size 467, which is longer than the specified 1
# Created a chunk of size 403, which is longer than the specified 1
# Created a chunk of size 375, which is longer than the specified 1
# Created a chunk of size 331, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 452, which is longer than the specified 1
# Created a chunk of size 368, which is longer than the specified 1
# Created a chunk of size 523, which is longer than the specified 1
# Created a chunk of size 668, which is longer than the specified 1
# Created a chunk of size 170, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 305, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 233, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 304, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 546, which is longer than the specified 1
# Created a chunk of size 179, which is longer than the specified 1
# Created a chunk of size 153, which is longer than the specified 1
# Created a chunk of size 151, which is longer than the specified 1
# Created a chunk of size 339, which is longer than the specified 1
# Created a chunk of size 701, which is longer than the specified 1
# Created a chunk of size 232, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 470, which is longer than the specified 1
# Created a chunk of size 379, which is longer than the specified 1
# Created a chunk of size 421, which is longer than the specified 1
# Created a chunk of size 475, which is longer than the specified 1
# Created a chunk of size 201, which is longer than the specified 1
# Created a chunk of size 175, which is longer than the specified 1
# Created a chunk of size 372, which is longer than the specified 1
# Created a chunk of size 396, which is longer than the specified 1
# Created a chunk of size 281, which is longer than the specified 1
# Created a chunk of size 192, which is longer than the specified 1
# Created a chunk of size 270, which is longer than the specified 1
# Created a chunk of size 298, which is longer than the specified 1
# Created a chunk of size 231, which is longer than the specified 1
# Created a chunk of size 324, which is longer than the specified 1
# Created a chunk of size 147, which is longer than the specified 1
# Created a chunk of size 332, which is longer than the specified 1
# Created a chunk of size 479, which is longer than the specified 1
# Created a chunk of size 444, which is longer than the specified 1
# Created a chunk of size 513, which is longer than the specified 1
# Created a chunk of size 246, which is longer than the specified 1
# Created a chunk of size 312, which is longer than the specified 1
# Created a chunk of size 311, which is longer than the specified 1
# Created a chunk of size 387, which is longer than the specified 1
# Created a chunk of size 179, which is longer than the specified 1
# Created a chunk of size 439, which is longer than the specified 1
# Created a chunk of size 380, which is longer than the specified 1
# Created a chunk of size 306, which is longer than the specified 1
# Created a chunk of size 522, which is longer than the specified 1
# Created a chunk of size 347, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 333, which is longer than the specified 1
# Created a chunk of size 285, which is longer than the specified 1
# Created a chunk of size 309, which is longer than the specified 1
# Created a chunk of size 331, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 331, which is longer than the specified 1
# Created a chunk of size 210, which is longer than the specified 1
# Created a chunk of size 231, which is longer than the specified 1
# Created a chunk of size 289, which is longer than the specified 1
# Created a chunk of size 591, which is longer than the specified 1
# Created a chunk of size 339, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 425, which is longer than the specified 1
# Created a chunk of size 912, which is longer than the specified 1
# Created a chunk of size 480, which is longer than the specified 1
# Created a chunk of size 218, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 186, which is longer than the specified 1
# Created a chunk of size 471, which is longer than the specified 1
# Created a chunk of size 324, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 171, which is longer than the specified 1
# Created a chunk of size 450, which is longer than the specified 1
# Created a chunk of size 155, which is longer than the specified 1
# Created a chunk of size 136, which is longer than the specified 1
# Created a chunk of size 154, which is longer than the specified 1
# Created a chunk of size 334, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 269, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 405, which is longer than the specified 1
# Created a chunk of size 282, which is longer than the specified 1
# Created a chunk of size 397, which is longer than the specified 1
# Created a chunk of size 191, which is longer than the specified 1
# Created a chunk of size 165, which is longer than the specified 1
# Created a chunk of size 296, which is longer than the specified 1
# Created a chunk of size 217, which is longer than the specified 1
# Created a chunk of size 167, which is longer than the specified 1
# Created a chunk of size 319, which is longer than the specified 1
# Created a chunk of size 155, which is longer than the specified 1
# Created a chunk of size 371, which is longer than the specified 1
# Created a chunk of size 537, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 190, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 369, which is longer than the specified 1
# Created a chunk of size 432, which is longer than the specified 1
# Created a chunk of size 419, which is longer than the specified 1
# Created a chunk of size 122, which is longer than the specified 1
# Created a chunk of size 418, which is longer than the specified 1
# Created a chunk of size 202, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 149, which is longer than the specified 1
# Created a chunk of size 173, which is longer than the specified 1
# Created a chunk of size 474, which is longer than the specified 1
# Created a chunk of size 254, which is longer than the specified 1
# Created a chunk of size 453, which is longer than the specified 1
# Created a chunk of size 454, which is longer than the specified 1
# Created a chunk of size 292, which is longer than the specified 1
# Created a chunk of size 458, which is longer than the specified 1
# Created a chunk of size 167, which is longer than the specified 1
# Created a chunk of size 446, which is longer than the specified 1
# Created a chunk of size 293, which is longer than the specified 1
# Created a chunk of size 268, which is longer than the specified 1
# Created a chunk of size 476, which is longer than the specified 1
# Created a chunk of size 464, which is longer than the specified 1
# Created a chunk of size 635, which is longer than the specified 1
# Created a chunk of size 342, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 633, which is longer than the specified 1
# Created a chunk of size 158, which is longer than the specified 1
# Created a chunk of size 533, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 171, which is longer than the specified 1
# Created a chunk of size 190, which is longer than the specified 1
# Created a chunk of size 181, which is longer than the specified 1
# Created a chunk of size 327, which is longer than the specified 1
# Created a chunk of size 333, which is longer than the specified 1
# Created a chunk of size 239, which is longer than the specified 1
# Created a chunk of size 126, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 402, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 153, which is longer than the specified 1
# Created a chunk of size 349, which is longer than the specified 1
# Created a chunk of size 369, which is longer than the specified 1
# Created a chunk of size 460, which is longer than the specified 1
# Created a chunk of size 165, which is longer than the specified 1
# Created a chunk of size 213, which is longer than the specified 1
# Created a chunk of size 321, which is longer than the specified 1
# Created a chunk of size 401, which is longer than the specified 1
# Created a chunk of size 233, which is longer than the specified 1
# Created a chunk of size 150, which is longer than the specified 1
# Created a chunk of size 108, which is longer than the specified 1
# Created a chunk of size 367, which is longer than the specified 1
# Created a chunk of size 364, which is longer than the specified 1
# Created a chunk of size 233, which is longer than the specified 1
# Created a chunk of size 285, which is longer than the specified 1
# Created a chunk of size 476, which is longer than the specified 1
# Created a chunk of size 212, which is longer than the specified 1
# Created a chunk of size 179, which is longer than the specified 1
# Created a chunk of size 325, which is longer than the specified 1
# Created a chunk of size 301, which is longer than the specified 1
# Created a chunk of size 373, which is longer than the specified 1
# Created a chunk of size 338, which is longer than the specified 1
# Created a chunk of size 470, which is longer than the specified 1
# Created a chunk of size 283, which is longer than the specified 1
# Created a chunk of size 565, which is longer than the specified 1
# Created a chunk of size 172, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 467, which is longer than the specified 1
# Created a chunk of size 643, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 351, which is longer than the specified 1
# Created a chunk of size 140, which is longer than the specified 1
# Created a chunk of size 272, which is longer than the specified 1
# Created a chunk of size 124, which is longer than the specified 1
# Created a chunk of size 463, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 366, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 380, which is longer than the specified 1
# Created a chunk of size 279, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 131, which is longer than the specified 1
# Created a chunk of size 167, which is longer than the specified 1
# Created a chunk of size 494, which is longer than the specified 1
# Created a chunk of size 630, which is longer than the specified 1
# Created a chunk of size 264, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 488, which is longer than the specified 1
# Created a chunk of size 596, which is longer than the specified 1
# Created a chunk of size 379, which is longer than the specified 1
# Created a chunk of size 142, which is longer than the specified 1
# Created a chunk of size 325, which is longer than the specified 1
# Created a chunk of size 157, which is longer than the specified 1
# Created a chunk of size 440, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 451, which is longer than the specified 1
# Created a chunk of size 221, which is longer than the specified 1
# Created a chunk of size 126, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 195, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 197, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 331, which is longer than the specified 1
# Created a chunk of size 231, which is longer than the specified 1
# Created a chunk of size 163, which is longer than the specified 1
# Created a chunk of size 154, which is longer than the specified 1
# Created a chunk of size 299, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 141, which is longer than the specified 1
# Created a chunk of size 343, which is longer than the specified 1
# Created a chunk of size 418, which is longer than the specified 1
# Created a chunk of size 147, which is longer than the specified 1
# Created a chunk of size 447, which is longer than the specified 1
# Created a chunk of size 148, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 254, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 383, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 283, which is longer than the specified 1
# Created a chunk of size 179, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 600, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 125, which is longer than the specified 1
# Created a chunk of size 270, which is longer than the specified 1
# Created a chunk of size 342, which is longer than the specified 1
# Created a chunk of size 360, which is longer than the specified 1
# Created a chunk of size 230, which is longer than the specified 1
# Created a chunk of size 451, which is longer than the specified 1
# Created a chunk of size 200, which is longer than the specified 1
# Created a chunk of size 315, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 301, which is longer than the specified 1
# Created a chunk of size 164, which is longer than the specified 1
# Created a chunk of size 435, which is longer than the specified 1
# Created a chunk of size 651, which is longer than the specified 1
# Created a chunk of size 328, which is longer than the specified 1
# Created a chunk of size 335, which is longer than the specified 1
# Created a chunk of size 405, which is longer than the specified 1
# Created a chunk of size 253, which is longer than the specified 1
# Created a chunk of size 347, which is longer than the specified 1
# Created a chunk of size 404, which is longer than the specified 1
# Created a chunk of size 564, which is longer than the specified 1
# Created a chunk of size 134, which is longer than the specified 1
# Created a chunk of size 395, which is longer than the specified 1
# Created a chunk of size 376, which is longer than the specified 1
# Created a chunk of size 162, which is longer than the specified 1
# Created a chunk of size 156, which is longer than the specified 1
# Created a chunk of size 377, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 411, which is longer than the specified 1
# Created a chunk of size 278, which is longer than the specified 1
# Created a chunk of size 158, which is longer than the specified 1
# Created a chunk of size 142, which is longer than the specified 1
# Created a chunk of size 324, which is longer than the specified 1
# Created a chunk of size 192, which is longer than the specified 1
# Created a chunk of size 443, which is longer than the specified 1
# Created a chunk of size 307, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 154, which is longer than the specified 1
# Created a chunk of size 563, which is longer than the specified 1
# Created a chunk of size 147, which is longer than the specified 1
# Created a chunk of size 343, which is longer than the specified 1
# Created a chunk of size 245, which is longer than the specified 1
# Created a chunk of size 349, which is longer than the specified 1
# Created a chunk of size 419, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 127, which is longer than the specified 1
# Created a chunk of size 334, which is longer than the specified 1
# Created a chunk of size 498, which is longer than the specified 1
# Created a chunk of size 274, which is longer than the specified 1
# Created a chunk of size 348, which is longer than the specified 1
# Created a chunk of size 155, which is longer than the specified 1
# Created a chunk of size 377, which is longer than the specified 1
# Created a chunk of size 161, which is longer than the specified 1
# Created a chunk of size 353, which is longer than the specified 1
# Created a chunk of size 271, which is longer than the specified 1
# Created a chunk of size 300, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 148, which is longer than the specified 1
# Created a chunk of size 203, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 359, which is longer than the specified 1
# Created a chunk of size 450, which is longer than the specified 1
# Created a chunk of size 611, which is longer than the specified 1
# Created a chunk of size 380, which is longer than the specified 1
# Created a chunk of size 339, which is longer than the specified 1
# Created a chunk of size 267, which is longer than the specified 1
# Created a chunk of size 145, which is longer than the specified 1
# Created a chunk of size 168, which is longer than the specified 1
# Created a chunk of size 364, which is longer than the specified 1
# Created a chunk of size 156, which is longer than the specified 1
# Created a chunk of size 121, which is longer than the specified 1
# Created a chunk of size 160, which is longer than the specified 1
# Created a chunk of size 267, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 270, which is longer than the specified 1
# Created a chunk of size 210, which is longer than the specified 1
# Created a chunk of size 338, which is longer than the specified 1
# Created a chunk of size 153, which is longer than the specified 1
# Created a chunk of size 212, which is longer than the specified 1
# Created a chunk of size 375, which is longer than the specified 1
# Created a chunk of size 317, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 444, which is longer than the specified 1
# Created a chunk of size 234, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 332, which is longer than the specified 1
# Created a chunk of size 262, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 199, which is longer than the specified 1
# Created a chunk of size 121, which is longer than the specified 1
# Created a chunk of size 318, which is longer than the specified 1
# Created a chunk of size 371, which is longer than the specified 1
# Created a chunk of size 367, which is longer than the specified 1
# Created a chunk of size 147, which is longer than the specified 1
# Created a chunk of size 303, which is longer than the specified 1
# Created a chunk of size 158, which is longer than the specified 1
# Created a chunk of size 403, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 554, which is longer than the specified 1
# Created a chunk of size 259, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 147, which is longer than the specified 1
# Created a chunk of size 292, which is longer than the specified 1
# Created a chunk of size 405, which is longer than the specified 1
# Created a chunk of size 155, which is longer than the specified 1
# Created a chunk of size 341, which is longer than the specified 1
# Created a chunk of size 324, which is longer than the specified 1
# Created a chunk of size 125, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 514, which is longer than the specified 1
# Created a chunk of size 334, which is longer than the specified 1
# Created a chunk of size 387, which is longer than the specified 1
# Created a chunk of size 687, which is longer than the specified 1
# Created a chunk of size 297, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 358, which is longer than the specified 1
# Created a chunk of size 399, which is longer than the specified 1
# Created a chunk of size 158, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 328, which is longer than the specified 1
# Created a chunk of size 544, which is longer than the specified 1
# Created a chunk of size 433, which is longer than the specified 1
# Created a chunk of size 338, which is longer than the specified 1
# Created a chunk of size 308, which is longer than the specified 1
# Created a chunk of size 197, which is longer than the specified 1
# Created a chunk of size 470, which is longer than the specified 1
# Created a chunk of size 312, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 260, which is longer than the specified 1
# Created a chunk of size 533, which is longer than the specified 1
# Created a chunk of size 136, which is longer than the specified 1
# Created a chunk of size 420, which is longer than the specified 1
# Created a chunk of size 669, which is longer than the specified 1
# Created a chunk of size 144, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 419, which is longer than the specified 1
# Created a chunk of size 142, which is longer than the specified 1
# Created a chunk of size 276, which is longer than the specified 1
# Created a chunk of size 265, which is longer than the specified 1
# Created a chunk of size 157, which is longer than the specified 1
# Created a chunk of size 256, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 380, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 227, which is longer than the specified 1
# Created a chunk of size 381, which is longer than the specified 1
# Created a chunk of size 453, which is longer than the specified 1
# Created a chunk of size 376, which is longer than the specified 1
# Created a chunk of size 390, which is longer than the specified 1
# Created a chunk of size 297, which is longer than the specified 1
# Created a chunk of size 118, which is longer than the specified 1
# Created a chunk of size 219, which is longer than the specified 1
# Created a chunk of size 201, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 186, which is longer than the specified 1
# Created a chunk of size 195, which is longer than the specified 1
# Created a chunk of size 203, which is longer than the specified 1
# Created a chunk of size 421, which is longer than the specified 1
# Created a chunk of size 423, which is longer than the specified 1
# Created a chunk of size 281, which is longer than the specified 1
# Created a chunk of size 492, which is longer than the specified 1
# Created a chunk of size 619, which is longer than the specified 1
# Created a chunk of size 378, which is longer than the specified 1
# Created a chunk of size 158, which is longer than the specified 1
# Created a chunk of size 436, which is longer than the specified 1
# Created a chunk of size 241, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 451, which is longer than the specified 1
# Created a chunk of size 185, which is longer than the specified 1
# Created a chunk of size 339, which is longer than the specified 1
# Created a chunk of size 363, which is longer than the specified 1
# Created a chunk of size 177, which is longer than the specified 1
# Created a chunk of size 400, which is longer than the specified 1
# Created a chunk of size 372, which is longer than the specified 1
# Created a chunk of size 163, which is longer than the specified 1
# Created a chunk of size 398, which is longer than the specified 1
# Created a chunk of size 352, which is longer than the specified 1
# Created a chunk of size 370, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 333, which is longer than the specified 1
# Created a chunk of size 223, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 277, which is longer than the specified 1
# Created a chunk of size 418, which is longer than the specified 1
# Created a chunk of size 166, which is longer than the specified 1
# Created a chunk of size 449, which is longer than the specified 1
# Created a chunk of size 268, which is longer than the specified 1
# Created a chunk of size 128, which is longer than the specified 1
# Created a chunk of size 335, which is longer than the specified 1
# Created a chunk of size 394, which is longer than the specified 1
# Created a chunk of size 144, which is longer than the specified 1
# Created a chunk of size 215, which is longer than the specified 1
# Created a chunk of size 395, which is longer than the specified 1
# Created a chunk of size 285, which is longer than the specified 1
# Created a chunk of size 389, which is longer than the specified 1
# Created a chunk of size 465, which is longer than the specified 1
# Created a chunk of size 141, which is longer than the specified 1
# Created a chunk of size 402, which is longer than the specified 1
# Created a chunk of size 313, which is longer than the specified 1
# Created a chunk of size 442, which is longer than the specified 1
# Created a chunk of size 156, which is longer than the specified 1
# Created a chunk of size 447, which is longer than the specified 1
# Created a chunk of size 310, which is longer than the specified 1
# Created a chunk of size 146, which is longer than the specified 1
# Created a chunk of size 359, which is longer than the specified 1
# Created a chunk of size 144, which is longer than the specified 1
# Created a chunk of size 452, which is longer than the specified 1
# Created a chunk of size 460, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 164, which is longer than the specified 1
# Created a chunk of size 442, which is longer than the specified 1
# Created a chunk of size 160, which is longer than the specified 1
# Created a chunk of size 349, which is longer than the specified 1
# Created a chunk of size 478, which is longer than the specified 1
# Created a chunk of size 397, which is longer than the specified 1
# Created a chunk of size 270, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 299, which is longer than the specified 1
# Created a chunk of size 476, which is longer than the specified 1
# Created a chunk of size 660, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 242, which is longer than the specified 1
# Created a chunk of size 303, which is longer than the specified 1
# Created a chunk of size 268, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 356, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 157, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 253, which is longer than the specified 1
# Created a chunk of size 342, which is longer than the specified 1
# Created a chunk of size 285, which is longer than the specified 1
# Created a chunk of size 218, which is longer than the specified 1
# Created a chunk of size 305, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 157, which is longer than the specified 1
# Created a chunk of size 252, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 345, which is longer than the specified 1
# Created a chunk of size 244, which is longer than the specified 1
# Created a chunk of size 205, which is longer than the specified 1
# Created a chunk of size 353, which is longer than the specified 1
# Created a chunk of size 151, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 211, which is longer than the specified 1
# Created a chunk of size 382, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 317, which is longer than the specified 1
# Created a chunk of size 162, which is longer than the specified 1
# Created a chunk of size 149, which is longer than the specified 1
# Created a chunk of size 368, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 376, which is longer than the specified 1
# Created a chunk of size 513, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 396, which is longer than the specified 1
# Created a chunk of size 300, which is longer than the specified 1
# Created a chunk of size 501, which is longer than the specified 1
# Created a chunk of size 402, which is longer than the specified 1
# Created a chunk of size 273, which is longer than the specified 1
# Created a chunk of size 241, which is longer than the specified 1
# Created a chunk of size 148, which is longer than the specified 1
# Created a chunk of size 474, which is longer than the specified 1
# Created a chunk of size 435, which is longer than the specified 1
# Created a chunk of size 285, which is longer than the specified 1
# Created a chunk of size 606, which is longer than the specified 1
# Created a chunk of size 482, which is longer than the specified 1
# Created a chunk of size 160, which is longer than the specified 1
# Created a chunk of size 396, which is longer than the specified 1
# Created a chunk of size 187, which is longer than the specified 1
# Created a chunk of size 414, which is longer than the specified 1
# Created a chunk of size 142, which is longer than the specified 1
# Created a chunk of size 301, which is longer than the specified 1
# Created a chunk of size 364, which is longer than the specified 1
# Created a chunk of size 219, which is longer than the specified 1
# Created a chunk of size 195, which is longer than the specified 1
# Created a chunk of size 421, which is longer than the specified 1
# Created a chunk of size 386, which is longer than the specified 1
# Created a chunk of size 346, which is longer than the specified 1
# Created a chunk of size 140, which is longer than the specified 1
# Created a chunk of size 235, which is longer than the specified 1
# Created a chunk of size 227, which is longer than the specified 1
# Created a chunk of size 155, which is longer than the specified 1
# Created a chunk of size 352, which is longer than the specified 1
# Created a chunk of size 382, which is longer than the specified 1
# Created a chunk of size 376, which is longer than the specified 1
# Created a chunk of size 394, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 279, which is longer than the specified 1
# ...
# Created a chunk of size 383, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 384, which is longer than the specified 1
# Created a chunk of size 194, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 160, which is longer than the specified 1
# Created a chunk of size 306, which is longer than the specified 1
# Created a chunk of size 294, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 263, which is longer than the specified 1
# Created a chunk of size 122, which is longer than the specified 1
# Created a chunk of size 286, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 354, which is longer than the specified 1
# Created a chunk of size 383, which is longer than the specified 1
# Created a chunk of size 128, which is longer than the specified 1
# Created a chunk of size 489, which is longer than the specified 1
# Created a chunk of size 442, which is longer than the specified 1
# Created a chunk of size 327, which is longer than the specified 1
# Created a chunk of size 171, which is longer than the specified 1
# Created a chunk of size 222, which is longer than the specified 1
# Created a chunk of size 354, which is longer than the specified 1
# Created a chunk of size 427, which is longer than the specified 1
# Created a chunk of size 210, which is longer than the specified 1
# Created a chunk of size 148, which is longer than the specified 1
# Created a chunk of size 154, which is longer than the specified 1
# Created a chunk of size 366, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 520, which is longer than the specified 1
# Created a chunk of size 160, which is longer than the specified 1
# Created a chunk of size 346, which is longer than the specified 1
# Created a chunk of size 126, which is longer than the specified 1
# Created a chunk of size 254, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 447, which is longer than the specified 1
# Created a chunk of size 128, which is longer than the specified 1
# Created a chunk of size 189, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 275, which is longer than the specified 1
# Created a chunk of size 409, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 442, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 204, which is longer than the specified 1
# Created a chunk of size 422, which is longer than the specified 1
# Created a chunk of size 450, which is longer than the specified 1
# Created a chunk of size 387, which is longer than the specified 1
# Created a chunk of size 337, which is longer than the specified 1
# Created a chunk of size 175, which is longer than the specified 1
# Created a chunk of size 599, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 159, which is longer than the specified 1
# Created a chunk of size 460, which is longer than the specified 1
# Created a chunk of size 158, which is longer than the specified 1
# Created a chunk of size 409, which is longer than the specified 1
# Created a chunk of size 438, which is longer than the specified 1
# Created a chunk of size 642, which is longer than the specified 1
# Created a chunk of size 311, which is longer than the specified 1
# Created a chunk of size 230, which is longer than the specified 1
# Created a chunk of size 169, which is longer than the specified 1
# Created a chunk of size 499, which is longer than the specified 1
# Created a chunk of size 229, which is longer than the specified 1
# Created a chunk of size 206, which is longer than the specified 1
# Created a chunk of size 299, which is longer than the specified 1
# Created a chunk of size 146, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 165, which is longer than the specified 1
# Created a chunk of size 287, which is longer than the specified 1
# Created a chunk of size 146, which is longer than the specified 1
# Created a chunk of size 193, which is longer than the specified 1
# Created a chunk of size 238, which is longer than the specified 1
# Created a chunk of size 485, which is longer than the specified 1
# Created a chunk of size 147, which is longer than the specified 1
# Created a chunk of size 314, which is longer than the specified 1
# Created a chunk of size 228, which is longer than the specified 1
# Created a chunk of size 131, which is longer than the specified 1
# Created a chunk of size 220, which is longer than the specified 1
# Created a chunk of size 225, which is longer than the specified 1
# Created a chunk of size 375, which is longer than the specified 1
# Created a chunk of size 444, which is longer than the specified 1
# Created a chunk of size 190, which is longer than the specified 1
# Created a chunk of size 322, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 207, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 509, which is longer than the specified 1
# Created a chunk of size 379, which is longer than the specified 1
# Created a chunk of size 218, which is longer than the specified 1
# Created a chunk of size 410, which is longer than the specified 1
# Created a chunk of size 210, which is longer than the specified 1
# Created a chunk of size 134, which is longer than the specified 1
# Created a chunk of size 329, which is longer than the specified 1
# Created a chunk of size 695, which is longer than the specified 1
# Created a chunk of size 202, which is longer than the specified 1
# Created a chunk of size 137, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 319, which is longer than the specified 1
# Created a chunk of size 333, which is longer than the specified 1
# Created a chunk of size 317, which is longer than the specified 1
# Created a chunk of size 365, which is longer than the specified 1
# Created a chunk of size 196, which is longer than the specified 1
# Created a chunk of size 178, which is longer than the specified 1
# Created a chunk of size 429, which is longer than the specified 1
# Created a chunk of size 172, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 128, which is longer than the specified 1
# Created a chunk of size 301, which is longer than the specified 1
# Created a chunk of size 137, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 162, which is longer than the specified 1
# Created a chunk of size 339, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 237, which is longer than the specified 1
# Created a chunk of size 138, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 170, which is longer than the specified 1
# Created a chunk of size 151, which is longer than the specified 1
# Created a chunk of size 368, which is longer than the specified 1
# Created a chunk of size 313, which is longer than the specified 1
# Created a chunk of size 158, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 599, which is longer than the specified 1
# Created a chunk of size 279, which is longer than the specified 1
# Created a chunk of size 250, which is longer than the specified 1
# Created a chunk of size 434, which is longer than the specified 1
# Created a chunk of size 216, which is longer than the specified 1
# Created a chunk of size 294, which is longer than the specified 1
# Created a chunk of size 305, which is longer than the specified 1
# Created a chunk of size 481, which is longer than the specified 1
# Created a chunk of size 277, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 195, which is longer than the specified 1
# Created a chunk of size 346, which is longer than the specified 1
# Created a chunk of size 349, which is longer than the specified 1
# Created a chunk of size 368, which is longer than the specified 1
# Created a chunk of size 203, which is longer than the specified 1
# Created a chunk of size 141, which is longer than the specified 1
# Created a chunk of size 409, which is longer than the specified 1
# Created a chunk of size 253, which is longer than the specified 1
# Created a chunk of size 527, which is longer than the specified 1
# Created a chunk of size 159, which is longer than the specified 1
# Created a chunk of size 157, which is longer than the specified 1
# Created a chunk of size 226, which is longer than the specified 1
# Created a chunk of size 298, which is longer than the specified 1
# Created a chunk of size 266, which is longer than the specified 1
# Created a chunk of size 164, which is longer than the specified 1
# Created a chunk of size 249, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1
# Created a chunk of size 331, which is longer than the specified 1
# Created a chunk of size 143, which is longer than the specified 1
# Created a chunk of size 341, which is longer than the specified 1
# Created a chunk of size 153, which is longer than the specified 1
# Created a chunk of size 183, which is longer than the specified 1
# Created a chunk of size 371, which is longer than the specified 1
# Created a chunk of size 190, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 149, which is longer than the specified 1
# Created a chunk of size 154, which is longer than the specified 1
# Created a chunk of size 539, which is longer than the specified 1
# Created a chunk of size 326, which is longer than the specified 1
# Created a chunk of size 132, which is longer than the specified 1
# Created a chunk of size 363, which is longer than the specified 1
# Created a chunk of size 274, which is longer than the specified 1
# Created a chunk of size 466, which is longer than the specified 1
# Created a chunk of size 158, which is longer than the specified 1
# Created a chunk of size 169, which is longer than the specified 1
# Created a chunk of size 573, which is longer than the specified 1
# Created a chunk of size 353, which is longer than the specified 1
# Created a chunk of size 385, which is longer than the specified 1
# Created a chunk of size 352, which is longer than the specified 1
# Created a chunk of size 179, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 160, which is longer than the specified 1
# Created a chunk of size 246, which is longer than the specified 1
# Created a chunk of size 240, which is longer than the specified 1
# Created a chunk of size 794, which is longer than the specified 1
# Created a chunk of size 241, which is longer than the specified 1
# Created a chunk of size 284, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 296, which is longer than the specified 1
# Created a chunk of size 418, which is longer than the specified 1
# Created a chunk of size 182, which is longer than the specified 1
# Created a chunk of size 223, which is longer than the specified 1
# Created a chunk of size 480, which is longer than the specified 1
# Created a chunk of size 272, which is longer than the specified 1
# Created a chunk of size 332, which is longer than the specified 1
# Created a chunk of size 157, which is longer than the specified 1
# Created a chunk of size 354, which is longer than the specified 1
# Created a chunk of size 288, which is longer than the specified 1
# Created a chunk of size 200, which is longer than the specified 1
# Created a chunk of size 362, which is longer than the specified 1
# Created a chunk of size 264, which is longer than the specified 1
# Created a chunk of size 188, which is longer than the specified 1
# Created a chunk of size 128, which is longer than the specified 1
# Created a chunk of size 170, which is longer than the specified 1
# Created a chunk of size 658, which is longer than the specified 1
# Created a chunk of size 329, which is longer than the specified 1
# Created a chunk of size 247, which is longer than the specified 1
# Created a chunk of size 258, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 129, which is longer than the specified 1
# Created a chunk of size 236, which is longer than the specified 1
# Created a chunk of size 299, which is longer than the specified 1
# Created a chunk of size 331, which is longer than the specified 1
# Created a chunk of size 469, which is longer than the specified 1
# Created a chunk of size 164, which is longer than the specified 1
# Created a chunk of size 127, which is longer than the specified 1
# Created a chunk of size 459, which is longer than the specified 1
# Created a chunk of size 176, which is longer than the specified 1
# Created a chunk of size 174, which is longer than the specified 1
# Created a chunk of size 508, which is longer than the specified 1
# Created a chunk of size 436, which is longer than the specified 1
# Created a chunk of size 310, which is longer than the specified 1
# Created a chunk of size 212, which is longer than the specified 1
# Created a chunk of size 230, which is longer than the specified 1
# Created a chunk of size 137, which is longer than the specified 1
# Created a chunk of size 345, which is longer than the specified 1
# Created a chunk of size 351, which is longer than the specified 1
# Created a chunk of size 339, which is longer than the specified 1
# Created a chunk of size 214, which is longer than the specified 1
# Created a chunk of size 334, which is longer than the specified 1
# Created a chunk of size 208, which is longer than the specified 1
# Created a chunk of size 421, which is longer than the specified 1
# Created a chunk of size 388, which is longer than the specified 1
# Created a chunk of size 399, which is longer than the specified 1
# Created a chunk of size 248, which is longer than the specified 1
# Created a chunk of size 434, which is longer than the specified 1
# Created a chunk of size 186, which is longer than the specified 1
# Created a chunk of size 407, which is longer than the specified 1
# Created a chunk of size 498, which is longer than the specified 1
# Created a chunk of size 380, which is longer than the specified 1
# Created a chunk of size 184, which is longer than the specified 1
# Created a chunk of size 334, which is longer than the specified 1
# Created a chunk of size 394, which is longer than the specified 1
# Created a chunk of size 389, which is longer than the specified 1
# Created a chunk of size 170, which is longer than the specified 1
# Created a chunk of size 167, which is longer than the specified 1
# Created a chunk of size 497, which is longer than the specified 1
# Created a chunk of size 344, which is longer than the specified 1
# Created a chunk of size 386, which is longer than the specified 1
# Created a chunk of size 257, which is longer than the specified 1

# %%
documents[0]
# Out:
# Document(metadata={'source': '../data/tagged_overview.txt'}, page_content='"tt1375666 Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: ""inception"", the implantation of another person\'s idea into a target\'s subconscious."')

# %% [markdown]
# **Импортируем модель для создания эмбеддингов**

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4340\614204990.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(

# %% [markdown]
# **Создаем векторную базу данных**

# %%
db_movies = Chroma.from_documents(
    documents,
    embedding=embeddings
)

# %% [markdown]
# **Выполняем семантический поиск в векторной базе данных по запросу**

# %%
query = "A movie about traveling in space"
docs = db_movies.similarity_search(query, k=5)
docs
# Out:
# [Document(id='54b1aacd-26dc-4d5b-85bd-6e7f9409282f', metadata={'source': '../data/tagged_overview.txt'}, page_content='"tt0133240 When space galleon cabin boy Jim Hawkins discovers a map to an intergalactic ""loot of a thousand worlds,"" a cyborg cook named John Silver teaches him to battle supernovas and space storms on their journey to find treasure."'),
#  Document(id='50e2f89a-8686-4bfd-acdf-895df557b900', metadata={'source': '../data/tagged_overview.txt'}, page_content='tt1355644 A spacecraft traveling to a distant colony planet and transporting thousands of people has a malfunction in its sleep chambers. As a result, two passengers are awakened 90 years early.'),
#  Document(id='6858c847-c7ba-47a2-99dd-cdfdfb7b9dd9', metadata={'source': '../data/tagged_overview.txt'}, page_content='tt1454468 Dr. Ryan Stone, a brilliant medical engineer on her first Shuttle mission, with veteran astronaut Matt Kowalsky in command of his last flight before retiring. But on a seemingly routine spacewalk, disaster strikes. The Shuttle is destroyed, leaving Stone and Kowalsky completely alone-tethered to nothing but each other and spiraling out into the blackness of space. The deafening silence tells them they have lost any link to Earth and any chance for rescue. As fear turns to panic, every gulp of air eats away at what little oxygen is left. But the only way home may be to go further out into the terrifying expanse of space.'),
#  Document(id='e589850e-a6bc-4199-bbf6-516c3c8dd5dd', metadata={'source': '../data/tagged_overview.txt'}, page_content='"tt1964418 Bound by a shared destiny, a bright, optimistic teen bursting with scientific curiosity and a former boy-genius inventor jaded by disillusionment embark on a danger-filled mission to unearth the secrets of an enigmatic place somewhere in time and space that exists in their collective memory as ""Tomorrowland."""'),
#  Document(id='eea82935-c31a-48ac-93a4-0cb87a5b9c4f', metadata={'source': '../data/tagged_overview.txt'}, page_content='tt0096874 Marty and Doc are at it again in this wacky sequel to the 1985 blockbuster as the time-traveling duo head to 2015 to nip some McFly family woes in the bud. But things go awry thanks to bully Biff Tannen and a pesky sports almanac. In a last-ditch attempt to set things straight, Marty finds himself bound for 1955 and face to face with his teenage parents -- again.')]

# %% [markdown]
# **Находим строку в датафрейме, которая соответствует первому результату семантического поиска**

# %%
movies[movies["imdb_id"] == (docs[0].page_content.split()[0].strip())]
# Out:
# Empty DataFrame
# Columns: [id, title, vote_average, vote_count, status, release_date, revenue, runtime, adult, backdrop_path, budget, homepage, imdb_id, original_language, overview, popularity, poster_path, tagline, genres, production_companies, production_countries, spoken_languages, keywords, tagged_overview]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# **Функция `retrieve_semantic_recommendations` выполняет поиск _top_k_ фильмов по запросу и возвращает _top_k_ фильмов**

# %%
def retrieve_semantic_recommendations(query: str, top_k: int = 5) -> pd.DataFrame:
    recs = db_movies.similarity_search(query, k=10)

    movies_list = []

    for i in range(0, len(recs)):
        movies_list += [recs[i].page_content.split()[0]]

    return movies[movies["imdb_id"].isin(movies_list)].head(top_k)

# %%
retrieve_semantic_recommendations(query)
# Out:
#          id                       title  vote_average  vote_count    status  \
# 1    157336                Interstellar         8.417       32571  Released
# 120   49047                     Gravity         7.162       14463  Released
# 166  274870                  Passengers         6.934       12429  Released
# 188     165  Back to the Future Part II         7.752       11817  Released
# 344  577922                       Tenet         7.191        8744  Released
#
#     release_date    revenue  runtime  adult                     backdrop_path  \
# 1     2014-11-05  701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg
# 120   2013-10-03  723192705       91  False  /a2n6bKD7qhCPCAEALgsAhWOAQcc.jpg
# 166   2016-12-21  303144152      116  False  /gHz4ZQytRs8YGrqFMwB3Vrr8pig.jpg
# 188   1989-11-22  332000000      108  False  /su0cmtK55eKXq0QjW68LQslUhUY.jpg
# 344   2020-08-22  365304105      150  False  /yY76zq9XSuJ4nWyPDuwkdV7Wt0c.jpg
#
#      ...                                           overview popularity  \
# 1    ...  The adventures of a group of explorers who mak...    140.241
# 120  ...  Dr. Ryan Stone, a brilliant medical engineer o...     31.024
# 166  ...  A spacecraft traveling to a distant colony pla...     27.272
# 188  ...  Marty and Doc are at it again in this wacky se...     30.516
# 344  ...  Armed with only one word - Tenet - and fightin...     44.025
#
#                           poster_path  \
# 1    /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 120  /kZ2nZw8D681aphje8NJi8EfbL1U.jpg
# 166  /jK9S6HANSf2no64v1x1HxfcpmcA.jpg
# 188  /hQq8xZe5uLjFzSBt4LanNP7SQjl.jpg
# 344  /aCIFMriQh8rvhxpN1IWGgvH0Tlg.jpg
#
#                                                tagline  \
# 1    Mankind was born on Earth. It was never meant ...
# 120                                       Don't Let Go
# 166                    There is a reason they woke up.
# 188     Roads? Where we're going, we don't need roads!
# 344                                     Time runs out.
#
#                                  genres  \
# 1     Adventure, Drama, Science Fiction
# 120    Science Fiction, Thriller, Drama
# 166     Drama, Romance, Science Fiction
# 188  Adventure, Comedy, Science Fiction
# 344   Action, Thriller, Science Fiction
#
#                                   production_companies  \
# 1    Legendary Pictures, Syncopy, Lynda Obst Produc...
# 120  Esperanto Filmoj, Warner Bros. Pictures, Heyda...
# 166  Wanda Pictures, Columbia Pictures, Village Roa...
# 188           Universal Pictures, Amblin Entertainment
# 344                     Warner Bros. Pictures, Syncopy
#
#                          production_countries   spoken_languages  \
# 1    United Kingdom, United States of America            English
# 120  United Kingdom, United States of America            English
# 166                  United States of America            English
# 188                  United States of America            English
# 344  United Kingdom, United States of America  English, Estonian
#
#                                               keywords  \
# 1    rescue, future, spacecraft, race against time,...
# 120  space mission, loss, space, astronaut, space s...
# 166  android, spacecraft, asteroid, isolation, show...
# 188  flying car, skateboarding, car race, lightning...
# 344  assassin, espionage, spy, time travel, mumbai ...
#
#                                        tagged_overview
# 1    tt0816692 The adventures of a group of explore...
# 120  tt1454468 Dr. Ryan Stone, a brilliant medical ...
# 166  tt1355644 A spacecraft traveling to a distant ...
# 188  tt0096874 Marty and Doc are at it again in thi...
# 344  tt6723592 Armed with only one word - Tenet - a...
#
# [5 rows x 24 columns]
